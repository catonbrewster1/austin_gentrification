# %% [markdown]
# # Visualizations

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import requests
import itertools
import matplotlib.pyplot as plt
import geopandas as gpd
import matplotlib.patches as mpatches
import mapclassify
sns.set()

# %%
zips = ('78701', '78702', '78703', '78704', '78705', '78717', '78719','78721',
        '78722', '78723', '78724', '78725', '78726', '78727', '78728', '78729',
        '78730', '78731', '78732', '78733', '78734', '78735', '78736', '78737',
        '78739', '78741', '78742', '78744', '78745', '78746', '78747', '78748',
        '78749', '78750', '78751', '78752', '78753', '78754', '78756', '78757',
        '78758', '78759', '78617', '78653', '78660')

# %%
df = pd.read_csv("clean_data/full_clean_data.csv").iloc[:,1:]
geo_zip_full = gpd.read_file("census_templates/ADP_zip_codes.geojson")

# %%
geo_zip = geo_zip_full[geo_zip_full['zipcode'].astype(str).isin(zips)]
geo_zip = geo_zip.loc[:,('zipcode', 'geometry')]

df['zipcode'] = df['zipcode'].astype(str)
df_geo = gpd.GeoDataFrame(pd.merge(df, geo_zip, on = ('zipcode'), how = 'outer'))

# %% [markdown]
# ## City Stats

# %%
df_geo.groupby('year').sum()['Dem: Pop']
# Out:
# year
# 2011    1018880.0
# 2012    1047947.0
# 2013    1074019.0
# 2014    1105821.0
# 2015    1135360.0
# 2016    1161832.0
# 2017    1187784.0
# 2018    1212705.0
# Name: Dem: Pop, dtype: float64

# %%
df_geo.groupby('year').mean()['Inc: PC Income']
# Out:
# year
# 2011    34758.200000
# 2012    35073.133333
# 2013    35865.577778
# 2014    36934.444444
# 2015    38192.355556
# 2016    39761.800000
# 2017    42228.533333
# 2018    44218.488889
# Name: Inc: PC Income, dtype: float64

# %%
df_geo.groupby('year').mean()['Hsg: Median House Costs'] # or 1Y: Hsg: Median Gross Rent
# Out:
# year
# 2011    1268.111111
# 2012    1283.200000
# 2013    1299.866667
# 2014    1309.177778
# 2015    1327.266667
# 2016    1368.444444
# 2017    1420.844444
# 2018    1482.622222
# Name: Hsg: Median House Costs, dtype: float64

# %% [markdown]
# ## Lineplots

# %%
df.groupby("zipcode").sum()['Gentrified 1Y Median'].sort_values(ascending = False)

# hand selected zips with >= 3 years of 1y gentrif from ^
gent1_zips = ['78704', '78721', '78734', '78756', '78723', '78751', '78748', '78737']

gent1 = df[df['zipcode'].isin(gent1_zips)]
rest1 = df[~df['zipcode'].isin(gent1_zips)]

# Lineplots about gentrified vs non gentrified zips
# change out var for 'Hsg: Median House Costs', 'Y: % built pre-1970', 'Inc: Income >100K',
#                    'Div: % NH White', 'Div: % Latino', 'Div: % Black'
plt.figure(figsize=(12, 12))

sns.lineplot(x = gent1['year'],
            y = gent1['Div: % Hispanic'],
            color = "green",
            linewidth = 5, 
             ci = None)

sns.lineplot(x = rest1['year'],
            y = rest1['Div: % Hispanic'],
            color = "blue",
            linewidth = 5,
             ci = None)

#plt.ylim(.5, .85)
plt.xlabel('Year', fontsize = 15)
plt.ylabel("Percent Residents Hispanic", fontsize = 15)
plt.title('Percent Hispanic Residents, 2011-2018', fontsize = 18)

zip_patch = mpatches.Patch(color='green', label='Gentrified')
austin_patch = mpatches.Patch(color='blue', label='Not Gentrified')

plt.legend(handles=[zip_patch, austin_patch])

None

# %% [markdown]
# ## Changes in median income by ZIP code between 2014 and 2019

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 91 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   year                                         360 non-null    int64
#  1   1 year                                       360 non-null    int64
#  2   5 years                                      360 non-null    int64
#  3   zipcode                                      360 non-null    object
#  4   Dem: Median Age                              360 non-null    float64
#  5   Dem: % <18                                   360 non-null    float64
#  6   Dem: Pop                                     360 non-null    float64
#  7   Div: % NH White                              360 non-null    float64
#  8   Div: % NH Black                              360 non-null    float64
#  9   Div: % Hispanic                              360 non-null    float64
#  10  Div: % NH Asian                              360 non-null    float64
#  11  Div: Max % One Race                          360 non-null    float64
#  12  Div: % Born in US                            360 non-null    float64
#  13  Ed: % Less than HS                           360 non-null    float64
#  14  Ed: % w/ Grad                                360 non-null    float64
#  15  Comp: % Married                              360 non-null    float64
#  16  Comp: % Fam HHs                              360 non-null    float64
#  17  Hsg: % Paying >20% Income on Housing         360 non-null    float64
#  18  Hsg: % Paying >30% Income on Housing         360 non-null    float64
#  19  Hsg: % Paying >40% Income on Housing         360 non-null    float64
#  20  Hsg: Median House Costs                      360 non-null    float64
#  21  Inc: Income >40K                             360 non-null    float64
#  22  Inc: Income >60K                             360 non-null    float64
#  23  Inc: Income >100K                            360 non-null    float64
#  24  Inc: PC Income                               360 non-null    float64
#  25  Inc: Gini Index                              360 non-null    float64
#  26  Mob: % Same House (1y)                       360 non-null    float64
#  27  Mob: % From Out of State (1y)                360 non-null    float64
#  28  Occ: % in Labor Force                        360 non-null    float64
#  29  Occ: % in mgmt/bus/science/arts              360 non-null    float64
#  30  Occ: % in serv/construct/prod                360 non-null    float64
#  31  Trns: % w/ 3+ Vehicles                       360 non-null    float64
#  32  Trns: % Walk/Bike to Work                    360 non-null    float64
#  33  Trns: % Public Trans to Work                 360 non-null    float64
#  34  Hsg: % Owner Occupied                        360 non-null    float64
#  35  Hsg: % Renter Occupied                       360 non-null    float64
#  36  Unt: % w/ 1                                  360 non-null    float64
#  37  Unt: % w/ 5+                                 360 non-null    float64
#  38  Unt: % w/ 50+                                360 non-null    float64
#  39  Unt: % w/ 3+bdrm                             360 non-null    float64
#  40  Unt: % w/ 1bdrm                              360 non-null    float64
#  41  Y: % built pre-1970                          360 non-null    float64
#  42  Y: % built pre-1940                          360 non-null    float64
#  43  Y: median yr built                           360 non-null    float64
#  44  com_permit_per_cap                           360 non-null    float64
#  45  res_permit_per_cap                           360 non-null    float64
#  46  assault_crime_per_cap                        360 non-null    float64
#  47  criminal_activity_crime_per_cap              360 non-null    float64
#  48  identity_theft_crime_per_cap                 360 non-null    float64
#  49  narcotics_crime_per_cap                      360 non-null    float64
#  50  public_intoxication_crime_per_cap            360 non-null    float64
#  51  runaway_child_crime_per_cap                  360 non-null    float64
#  52  theft_crime_per_cap                          360 non-null    float64
#  53  warrent_arrest_crime_per_cap                 360 non-null    float64
#  54  Dem: Pop Density                             360 non-null    float64
#  55  1Y: Inc: Median Income Past 12m              306 non-null    float64
#  56  1Y: Ed: % w/ BA                              315 non-null    float64
#  57  1Y: Hsg: Median Gross Rent                   315 non-null    float64
#  58  1Y: Hsg: Median House Val                    315 non-null    float64
#  59  5Y: Inc: Median Income Past 12m              135 non-null    float64
#  60  5Y: Ed: % w/ BA                              135 non-null    float64
#  61  5Y: Hsg: Median Gross Rent                   135 non-null    float64
#  62  5Y: Hsg: Median House Val                    135 non-null    float64
#  63  1Y CHG: Inc: Median Income Past 12m          297 non-null    float64
#  64  5Y CHG: Inc: Median Income Past 12m          135 non-null    float64
#  65  1Y CHG > Median Inc: Median Income Past 12m  360 non-null    bool
#  66  5Y CHG > Median Inc: Median Income Past 12m  360 non-null    bool
#  67  1Y CHG > 75th Inc: Median Income Past 12m    360 non-null    bool
#  68  5Y CHG > 75th Inc: Median Income Past 12m    360 non-null    bool
#  69  1Y CHG: Ed: % w/ BA                          315 non-null    float64
#  70  5Y CHG: Ed: % w/ BA                          135 non-null    float64
#  71  1Y CHG > Median Ed: % w/ BA                  360 non-null    bool
#  72  5Y CHG > Median Ed: % w/ BA                  360 non-null    bool
#  73  1Y CHG > 75th Ed: % w/ BA                    360 non-null    bool
#  74  5Y CHG > 75th Ed: % w/ BA                    360 non-null    bool
#  75  1Y CHG: Hsg: Median Gross Rent               315 non-null    float64
#  76  5Y CHG: Hsg: Median Gross Rent               135 non-null    float64
#  77  1Y CHG > Median Hsg: Median Gross Rent       360 non-null    bool
#  78  5Y CHG > Median Hsg: Median Gross Rent       360 non-null    bool
#  79  1Y CHG > 75th Hsg: Median Gross Rent         360 non-null    bool
#  80  5Y CHG > 75th Hsg: Median Gross Rent         360 non-null    bool
#  81  1Y CHG: Hsg: Median House Val                315 non-null    float64
#  82  5Y CHG: Hsg: Median House Val                135 non-null    float64
#  83  1Y CHG > Median Hsg: Median House Val        360 non-null    bool
#  84  5Y CHG > Median Hsg: Median House Val        360 non-null    bool
#  85  1Y CHG > 75th Hsg: Median House Val          360 non-null    bool
#  86  5Y CHG > 75th Hsg: Median House Val          360 non-null    bool
#  87  Gentrified 1Y Median                         360 non-null    bool
#  88  Gentrified 1Y 75th                           360 non-null    bool
#  89  Gentrified 5Y Median                         360 non-null    bool
#  90  Gentrified 5Y 75th                           360 non-null    bool
# dtypes: bool(20), float64(67), int64(3), object(1)
# memory usage: 206.8+ KB

# %%
zip_graph = df[["year","zipcode",'5Y CHG: Inc: Median Income Past 12m']][df["year"]==2014]
zip_graph = zip_graph.reset_index()
zip_graph = zip_graph.sort_values("5Y CHG: Inc: Median Income Past 12m")
avg_change = df[["year","zipcode","5Y CHG: Inc: Median Income Past 12m"]][df["year"]==2014].iloc[:,2].mean()

# %%
plt.figure(figsize=(16,8))
p = sns.barplot(data=zip_graph, 
                x="zipcode", 
                y="5Y CHG: Inc: Median Income Past 12m",
                palette="crest")


for i, bar in enumerate(p.patches):
    if (i == 1 or i == len(p.patches)-1):
      p.annotate(format(bar.get_height(), '.0f'), 
                   (bar.get_x() + bar.get_width() / 2., bar.get_height()), 
                   ha = 'center', va = 'center', rotation=45,
                   xytext = (5, 18), 
                   textcoords = 'offset points')
    
p = plt.xticks(rotation=45, horizontalalignment='right')
p = plt.ylim(0, 22000)
p = plt.xlabel("ZIP Code")
p = plt.ylabel("Change in Median Income 2014-2019")
p = plt.title("Changes in Median Income 2014-2019 by ZIP Code Compared to Austin Average")

plt.axhline(avg_change, color="orange", linewidth = 3, linestyle = "--")

plt.show(p)

# %% [markdown]
# ## City Maps

# %%
fig, (ax, ax2) = plt.subplots(2, figsize=(25,25))
ax.axis("off")
ax2.axis("off")

ax.set_title("Population Density by Zip Code, 2011", fontsize = 24)

df_geo[df_geo['year'] == 2011].plot(column = 'Dem: Pop Density', 
                  linewidth=0.8, ax=ax, edgecolor="0.8", 
                  scheme = 'quantiles',legend=True,legend_kwds=dict(loc='upper right',fontsize='large',
                  frameon=True),
                  cmap='Greys')
ax2.set_title("Population Density by Zip Code, 2018", fontsize = 24)

df_geo[df_geo['year'] == 2018].plot(column = 'Dem: Pop Density', 
                  linewidth=0.8, ax=ax2, edgecolor="0.8", 
                  scheme = 'quantiles',legend=True,legend_kwds=dict(loc='upper right',fontsize='large',
                  frameon=True),
                  cmap='Greys')

# ax.legend(fontsize=18)
# ax2.legend(fontsize=18)
# Out:
# <AxesSubplot:title={'center':'Population Density by Zip Code, 2018'}>

# %%
df.columns
# Out:
# Index(['year', '1 year', '5 years', 'zipcode', 'Dem: Median Age', 'Dem: % <18',
#        'Dem: Pop', 'Div: % NH White', 'Div: % NH Black', 'Div: % Hispanic',
#        'Div: % NH Asian', 'Div: Max % One Race', 'Div: % Born in US',
#        'Ed: % Less than HS', 'Ed: % w/ Grad', 'Comp: % Married',
#        'Comp: % Fam HHs', 'Hsg: % Paying >20% Income on Housing',
#        'Hsg: % Paying >30% Income on Housing',
#        'Hsg: % Paying >40% Income on Housing', 'Hsg: Median House Costs',
#        'Inc: Income >40K', 'Inc: Income >60K', 'Inc: Income >100K',
#        'Inc: PC Income', 'Inc: Gini Index', 'Mob: % Same House (1y)',
#        'Mob: % From Out of State (1y)', 'Occ: % in Labor Force',
#        'Occ: % in mgmt/bus/science/arts', 'Occ: % in serv/construct/prod',
#        'Trns: % w/ 3+ Vehicles', 'Trns: % Walk/Bike to Work',
#        'Trns: % Public Trans to Work', 'Hsg: % Owner Occupied',
#        'Hsg: % Renter Occupied', 'Unt: % w/ 1', 'Unt: % w/ 5+',
#        'Unt: % w/ 50+', 'Unt: % w/ 3+bdrm', 'Unt: % w/ 1bdrm',
#        'Y: % built pre-1970', 'Y: % built pre-1940', 'Y: median yr built',
#        'com_permit_per_cap', 'res_permit_per_cap', 'assault_crime_per_cap',
#        'criminal_activity_crime_per_cap', 'identity_theft_crime_per_cap',
#        'narcotics_crime_per_cap', 'public_intoxication_crime_per_cap',
#        'runaway_child_crime_per_cap', 'theft_crime_per_cap',
#        'warrent_arrest_crime_per_cap', 'Dem: Pop Density',
#        '1Y: Inc: Median Income Past 12m', '1Y: Ed: % w/ BA',
#        '1Y: Hsg: Median Gross Rent', '1Y: Hsg: Median House Val',
#        '5Y: Inc: Median Income Past 12m', '5Y: Ed: % w/ BA',
#        '5Y: Hsg: Median Gross Rent', '5Y: Hsg: Median House Val',
#        '1Y CHG: Inc: Median Income Past 12m',
#        '5Y CHG: Inc: Median Income Past 12m',
#        '1Y CHG > Median Inc: Median Income Past 12m',
#        '5Y CHG > Median Inc: Median Income Past 12m',
#        '1Y CHG > 75th Inc: Median Income Past 12m',
#        '5Y CHG > 75th Inc: Median Income Past 12m', '1Y CHG: Ed: % w/ BA',
#        '5Y CHG: Ed: % w/ BA', '1Y CHG > Median Ed: % w/ BA',
#        '5Y CHG > Median Ed: % w/ BA', '1Y CHG > 75th Ed: % w/ BA',
#        '5Y CHG > 75th Ed: % w/ BA', '1Y CHG: Hsg: Median Gross Rent',
#        '5Y CHG: Hsg: Median Gross Rent',
#        '1Y CHG > Median Hsg: Median Gross Rent',
#        '5Y CHG > Median Hsg: Median Gross Rent',
#        '1Y CHG > 75th Hsg: Median Gross Rent',
#        '5Y CHG > 75th Hsg: Median Gross Rent', '1Y CHG: Hsg: Median House Val',
#        '5Y CHG: Hsg: Median House Val',
#        '1Y CHG > Median Hsg: Median House Val',
#        '5Y CHG > Median Hsg: Median House Val',
#        '1Y CHG > 75th Hsg: Median House Val',
#        '5Y CHG > 75th Hsg: Median House Val', 'Gentrified 1Y Median',
#        'Gentrified 1Y 75th', 'Gentrified 5Y Median', 'Gentrified 5Y 75th'],
#       dtype='object')

# %%
df_geo['5Y CHG: Hsg: Median House Val'] = df_geo['5Y CHG: Hsg: Median House Val'][df_geo['5Y CHG: Hsg: Median House Val']>0]

# %%
fig,ax = plt.subplots(1, figsize=(14,14))
ax.axis("off")
ax.set_title("5 Year Change in Median House Value, 2014-2019", fontsize = 24)
df_geo[df_geo['year'] == 2014].plot(column = '5Y CHG: Hsg: Median House Val', 
                  linewidth=0.8, ax=ax, edgecolor="0.8", 
                  scheme = 'quantiles',legend=True,cmap='Greens',legend_kwds=dict(loc='upper right',fontsize='large',
                  frameon=True))

plt.show()
# Out:
# /Users/andrescrucettanieto/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/andrescrucettanieto/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/andrescrucettanieto/opt/anaconda3/lib/python3.8/site-packages/mapclassify/classifiers.py:887: RuntimeWarning: invalid value encountered in double_scalars
#   gadf = 1 - self.adcm / adam
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-edaad93ab8e5> in <module>
#       2 ax.axis("off")
#       3 ax.set_title("5 Year Change in Median House Value, 2014-2019", fontsize = 24)
# ----> 4 df_geo[df_geo['year'] == 2014].plot(column = '5Y CHG: Hsg: Median House Val',
#       5                   linewidth=0.8, ax=ax, edgecolor="0.8",
#       6                   scheme = 'quantiles',legend=True,cmap='Greens',legend_kwds=dict(loc='upper right',fontsize='large',
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/plotting.py in __call__(self, *args, **kwargs)
#     923             kind = kwargs.pop("kind", "geo")
#     924             if kind == "geo":
# --> 925                 return plot_dataframe(data, *args, **kwargs)
#     926             if kind in self._pandas_kinds:
#     927                 # Access pandas plots
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     768                 fmt = legend_kwds.pop("fmt")
#     769
# --> 770             categories = binning.get_legend_classes(fmt)
#     771             if legend_kwds is not None:
#     772                 show_interval = legend_kwds.pop("interval", False)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mapclassify/classifiers.py in get_legend_classes(self, fmt)
#     972                k strings with class interval definitions
#     973         """
# --> 974         return _get_mpl_labels(self, fmt)
#     975
#     976     def plot(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mapclassify/classifiers.py in _get_mpl_labels(mc, fmt)
#     123              k strings for class intervals
#     124     """
# --> 125     edges, max_width, lower_open = _format_intervals(mc, fmt)
#     126     k = len(edges) - 1
#     127     left = ["["]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mapclassify/classifiers.py in _format_intervals(mc, fmt)
#      94     """
#      95
# ---> 96     lowest = mc.y.min()
#      97     lower_open = False
#      98     if lowest > mc.bins[0]:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      41 def _amin(a, axis=None, out=None, keepdims=False,
#      42           initial=_NoValue, where=True):
# ---> 43     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      44
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
fig,ax = plt.subplots(1, figsize=(14,14))
ax.axis("off")
ax.set_title("5 Year Change in Median Income, 2014-2019", fontsize = 24)
df_geo[df_geo['year'] == 2014].plot(column = '5Y CHG: Inc: Median Income Past 12m', 
                  linewidth=0.8, ax=ax, edgecolor="0.8", 
                  scheme = 'naturalbreaks',legend=True,cmap='Greens',legend_kwds=dict(loc='upper right',fontsize='large',
                  frameon=True))

plt.show()

# %%
# df_geo['Gentrified 1Y Median'] = np.where(df['Gentrified 1Y Median']==True, 'Gentrified', 'Not Gentrified')
zip_gentrified = df_geo.groupby('zipcode')['Gentrified 1Y Median'].sum().reset_index()

# %%
df_geo_gentrified = gpd.GeoDataFrame(pd.merge(zip_gentrified, geo_zip, on = ('zipcode'), how = 'outer'))

# %%
fig,ax = plt.subplots(1, figsize=(14,14))
ax.axis("off")
ax.set_title("Number of Years Each Zipcode Gentrified", fontsize = 24)
df_geo_gentrified.plot(column = 'Gentrified 1Y Median', 
                  linewidth=0.8, ax=ax, edgecolor="0.8",legend=True, cmap='Reds',scheme='natural_breaks',
                  legend_kwds=dict(loc='upper right',fontsize='large',
                  frameon=True))

plt.show()

# %% [markdown]
# ## Demographic Map

# %%
# Creating column with common race
df_geo['most_common_race'] = df_geo.values[:,7:10].argmax(1)+1

def label_race(row):
  if row['most_common_race'] == 1:
    return "White"
  elif row['most_common_race'] == 2:
    return "Black"
  elif row['most_common_race'] == 3:
    return "Latino"
  else:
    return "Other"

# %%
df_geo['race_label'] = df_geo.apply(lambda row: label_race(row), axis=1)

# %%
df_geo.head()

# %%
fig,ax = plt.subplots(1, figsize=(14,14))
ax.axis("off")
ax.set_title("% of Hispanic Population by Zip Code, 2018", fontsize = 24)
df_geo[df_geo['year'] == 2018].plot(column = 'Div: % Hispanic', 
                  linewidth=0.8, ax=ax, edgecolor="0.8",legend=True,
                  scheme='quantiles',cmap='Greys',legend_kwds=dict(loc='upper right',fontsize='large',
                  frameon=True))

df_geo.loc[(df_geo['year'] == 2018)&(df_geo['Gentrified 1Y Median'] == True)].dissolve('Gentrified 1Y Median').plot(legend=True, ax=ax, facecolor='none', edgecolor='blue', linewidth=1.5, alpha=1)

plt.show()

# %%
fig,ax = plt.subplots(1, figsize=(14,14))
ax.axis("off")
ax.set_title("% of Hispanic Population by Zip Code, 2012", fontsize = 24)
df_geo[df_geo['year'] == 2012].plot(column = 'Div: % Hispanic', 
                  linewidth=0.8, ax=ax, edgecolor="0.8",legend=True,
                  scheme='quantiles',cmap='Greys',legend_kwds=dict(loc='upper right',fontsize='large',
                  frameon=True))

df_geo.loc[(df_geo['year'] == 2012)&(df_geo['Gentrified 1Y Median'] == True)].dissolve('Gentrified 1Y Median').plot(legend=True, ax=ax, facecolor='none', edgecolor='blue', linewidth=1.5, alpha=1)

plt.show()
